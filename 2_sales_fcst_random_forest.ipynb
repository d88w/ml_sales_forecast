# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

from sklearn.linear_model import Lasso
from sklearn.isotonic import IsotonicRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

from IPython.display import display # Allows the use of display() for DataFrames

# Pretty display for notebooks
# %matplotlib inline

# %%
# Load the data 
full_data = pd.read_csv("/Users/derekwang/Desktop/Python/Sales Forecast/training_data_FY18_2H_FY19_All.csv")

# %%
# Define outcome
outcomes_raw = full_data[['bookings_pct_finish']]

# Define features
features_raw = full_data.drop(['bookings_pct_finish'], axis = 1)

# display(features_raw.head())
print(features_raw.columns)
# features_raw.describe()
# Out:
# Index(['dt', 'fy_quarter', 'day_of_qtr', 'sales_div', 'quota', 'stage_1_count',
#        'stage_1_amount', 'stage_2_count', 'stage_2_amount', 'stage_3_count',
#        'stage_3_amount', 'stage_4_count', 'stage_4_amount', 'stage_5_count',
#        'stage_5_amount', 'bookings_qtd', 'direct_bookings', 'qtr_pct',
#        's1_quota_ratio', 's2_quota_ratio', 's3_quota_ratio', 's4_quota_ratio',
#        's5_quota_ratio', 's12345_bk_qtd_quota_ratio',
#        's2345_bk_qtd_quota_ratio', 's345_bk_qtd_quota_ratio',
#        's45_bk_qtd_quota_ratio', 's5_bk_qtd_quota_ratio', 'bookings_pct_qtd'],
#       dtype='object')

# %%
# fill in NA's with 0 - FEATURES
features = features_raw.fillna(0.0)
# display(features.head())
print(features.columns)


# fill in NA's with 0 - OUTCOMES
outcomes = outcomes_raw.fillna(0.0)
# display(outcomes.head())
print(outcomes.columns)
# Out:
# Index(['dt', 'fy_quarter', 'day_of_qtr', 'sales_div', 'quota', 'stage_1_count',
#        'stage_1_amount', 'stage_2_count', 'stage_2_amount', 'stage_3_count',
#        'stage_3_amount', 'stage_4_count', 'stage_4_amount', 'stage_5_count',
#        'stage_5_amount', 'bookings_qtd', 'direct_bookings', 'qtr_pct',
#        's1_quota_ratio', 's2_quota_ratio', 's3_quota_ratio', 's4_quota_ratio',
#        's5_quota_ratio', 's12345_bk_qtd_quota_ratio',
#        's2345_bk_qtd_quota_ratio', 's345_bk_qtd_quota_ratio',
#        's45_bk_qtd_quota_ratio', 's5_bk_qtd_quota_ratio', 'bookings_pct_qtd'],
#       dtype='object')
# Index(['bookings_pct_finish'], dtype='object')

# %%
# split test set and train set
X_train_raw, X_test_raw, y_train, y_test = train_test_split(features, outcomes, test_size=0.2, random_state=42)

# %%
# drop features and columns that are not needed

X_train_raw2 = X_train_raw.drop(['dt', 'fy_quarter', 'day_of_qtr', 'quota', 'stage_1_count', 'stage_1_amount', 
                          'stage_2_count', 'stage_2_amount', 'stage_3_count', 'stage_3_amount', 'stage_4_count', 
                          'stage_4_amount', 'stage_5_count', 'stage_5_amount', 'bookings_qtd', 'direct_bookings',
                          's1_quota_ratio', 's2_quota_ratio', 's3_quota_ratio', 's4_quota_ratio','s5_quota_ratio'
                                ], 
                                axis = 1)

X_test_raw2 = X_test_raw.drop(['dt', 'fy_quarter', 'day_of_qtr', 'quota', 'stage_1_count', 'stage_1_amount', 
                          'stage_2_count', 'stage_2_amount', 'stage_3_count', 'stage_3_amount', 'stage_4_count', 
                          'stage_4_amount', 'stage_5_count', 'stage_5_amount', 'bookings_qtd', 'direct_bookings',
                          's1_quota_ratio', 's2_quota_ratio', 's3_quota_ratio', 's4_quota_ratio','s5_quota_ratio'
                              ], 
                              axis = 1)

# %%
# One-hot encoding
X_train = pd.get_dummies(X_train_raw2)
X_test = pd.get_dummies(X_test_raw2)

# %%
# get rid of blanks in headers

X_train.columns = X_train.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
print('X_train columns')
print(X_train.columns)
display(X_train.head())

X_test.columns = X_test.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
print('X_test columns')
print(X_test.columns)
display(X_test.head())
# Out:
# X_train columns
# Index(['qtr_pct', 's12345_bk_qtd_quota_ratio', 's2345_bk_qtd_quota_ratio',
#        's345_bk_qtd_quota_ratio', 's45_bk_qtd_quota_ratio',
#        's5_bk_qtd_quota_ratio', 'bookings_pct_qtd', 'sales_div_api',
#        'sales_div_comm', 'sales_div_comm-vast', 'sales_div_ed',
#        'sales_div_ent', 'sales_div_gov', 'sales_div_healthcare',
#        'sales_div_intl', 'sales_div_intl-anz', 'sales_div_intl-apac',
#        'sales_div_intl-emea', 'sales_div_intl-uk', 'sales_div_majors',
#        'sales_div_network_alliance', 'sales_div_smb', 'sales_div_smb-vast'],
#       dtype='object')
#        qtr_pct  s12345_bk_qtd_quota_ratio  s2345_bk_qtd_quota_ratio  \
# 120   0.404494                   0.519234                  0.515171
# 3849  0.505618                   1.183806                  1.098117
# 4595  0.651685                   2.445669                  2.404535
# 1780  0.516854                   3.133690                  3.111000
# 4304  0.467391                   1.919407                  1.875831
#
#       s345_bk_qtd_quota_ratio  s45_bk_qtd_quota_ratio  s5_bk_qtd_quota_ratio  \
# 120                  0.431897                0.330031               0.235123
# 3849                 0.914530                0.751672               0.664627
# 4595                 1.732103                1.374839               0.952292
# 1780                 1.644095                0.997809               0.866381
# 4304                 1.555836                0.959988               0.635071
#
#       bookings_pct_qtd  sales_div_api  sales_div_comm  sales_div_comm-vast  \
# 120           0.147354              0               0                    1
# 3849          0.572771              0               0                    0
# 4595          0.930331              0               0                    0
# 1780          0.459881              0               0                    0
# 4304          0.558932              0               0                    0
#
#       ...  sales_div_healthcare  sales_div_intl  sales_div_intl-anz  \
# 120   ...                     0               0                   0
# 3849  ...                     0               0                   0
# 4595  ...                     0               0                   1
# 1780  ...                     0               0                   0
# 4304  ...                     0               1                   0
#
#       sales_div_intl-apac  sales_div_intl-emea  sales_div_intl-uk  \
# 120                     0                    0                  0
# 3849                    0                    0                  0
# 4595                    0                    0                  0
# 1780                    0                    0                  0
# 4304                    0                    0                  0
#
#       sales_div_majors  sales_div_network_alliance  sales_div_smb  \
# 120                  0                           0              0
# 3849                 0                           0              0
# 4595                 0                           0              0
# 1780                 0                           1              0
# 4304                 0                           0              0
#
#       sales_div_smb-vast
# 120                    0
# 3849                   1
# 4595                   0
# 1780                   0
# 4304                   0
#
# [5 rows x 23 columns]
# X_test columns
# Index(['qtr_pct', 's12345_bk_qtd_quota_ratio', 's2345_bk_qtd_quota_ratio',
#        's345_bk_qtd_quota_ratio', 's45_bk_qtd_quota_ratio',
#        's5_bk_qtd_quota_ratio', 'bookings_pct_qtd', 'sales_div_api',
#        'sales_div_comm', 'sales_div_comm-vast', 'sales_div_ed',
#        'sales_div_ent', 'sales_div_gov', 'sales_div_healthcare',
#        'sales_div_intl', 'sales_div_intl-anz', 'sales_div_intl-apac',
#        'sales_div_intl-emea', 'sales_div_intl-uk', 'sales_div_majors',
#        'sales_div_network_alliance', 'sales_div_smb', 'sales_div_smb-vast'],
#       dtype='object')
#        qtr_pct  s12345_bk_qtd_quota_ratio  s2345_bk_qtd_quota_ratio  \
# 1583  0.358696                   2.089514                  1.981656
# 3199  0.054348                   1.656270                  1.520276
# 3860  0.629213                   1.372473                  1.266091
# 2554  0.978261                   4.052103                  3.440547
# 168   0.943820                   0.844769                  0.836183
#
#       s345_bk_qtd_quota_ratio  s45_bk_qtd_quota_ratio  s5_bk_qtd_quota_ratio  \
# 1583                 1.513368                0.948736               0.464720
# 3199                 0.893199                0.340353               0.126554
# 3860                 1.067916                0.906049               0.819606
# 2554                 2.695283                1.529301               1.178561
# 168                  0.753523                0.610513               0.507024
#
#       bookings_pct_qtd  sales_div_api  sales_div_comm  sales_div_comm-vast  \
# 1583          0.234820              0               0                    0
# 3199          0.030078              0               0                    0
# 3860          0.742356              0               0                    0
# 2554          0.810855              0               0                    0
# 168           0.394058              0               0                    1
#
#       ...  sales_div_healthcare  sales_div_intl  sales_div_intl-anz  \
# 1583  ...                     0               0                   0
# 3199  ...                     0               0                   0
# 3860  ...                     0               0                   0
# 2554  ...                     1               0                   0
# 168   ...                     0               0                   0
#
#       sales_div_intl-apac  sales_div_intl-emea  sales_div_intl-uk  \
# 1583                    0                    0                  0
# 3199                    0                    0                  1
# 3860                    0                    0                  0
# 2554                    0                    0                  0
# 168                     0                    0                  0
#
#       sales_div_majors  sales_div_network_alliance  sales_div_smb  \
# 1583                 0                           0              0
# 3199                 0                           0              0
# 3860                 0                           0              0
# 2554                 0                           0              0
# 168                  0                           0              0
#
#       sales_div_smb-vast
# 1583                   0
# 3199                   0
# 3860                   1
# 2554                   0
# 168                    0
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Documentations needed:
#
# #### RandomForestRegressor
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html
#
# #### GridSearchCV
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
#
# #### make_scorer
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.make_scorer.html

# %%
## TUNING using grid search, also using customized scoring system

from sklearn.metrics import make_scorer, accuracy_score
from sklearn.model_selection import GridSearchCV

# Choose the type of classifier. 
rf = RandomForestRegressor(n_estimators=100)

# Choose some parameter combinations to try
parameters = {'max_depth': [None,2,3,5,10], 
              'min_samples_split': [2,3,5,20],
              'min_samples_leaf': [3,4,5,10,50]
             }

# Type of scoring used to compare parameter combinations
def avg_abs_var_finish(y_test,y_test_hat):
    var_finish = np.subtract(y_test,y_test_hat)
    abs_var_finish = abs(var_finish)
    av_abs_var_finish = np.mean(abs_var_finish)
    return av_abs_var_finish
    
my_scorer = make_scorer(avg_abs_var_finish, greater_is_better=False)

# Run the grid search
grid_obj = GridSearchCV(rf, parameters, scoring=my_scorer, verbose=3, cv=5)
cv = grid_obj.fit(X_train, y_train.bookings_pct_finish)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=2 .........
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=2, score=-0.031390921630468374, total=   1.9s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=2 .........
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=2, score=-0.0326868259476073, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=2 .........
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.5s remaining:    0.0s
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=2, score=-0.02953475255903885, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=2 .........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=2, score=-0.031468179443344776, total=   1.6s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=2 .........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=2, score=-0.029892264863130243, total=   1.6s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=3 .........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=3, score=-0.03128407090714591, total=   1.6s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=3 .........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=3, score=-0.03297589207292121, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=3 .........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=3, score=-0.029797395075668996, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=3 .........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=3, score=-0.031634154045734796, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=3 .........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=3, score=-0.029386590293813134, total=   1.7s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=5 .........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=5, score=-0.03184883896273111, total=   1.6s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=5 .........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=5, score=-0.03304350253322683, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=5 .........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=5, score=-0.02983240172364893, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=5 .........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=5, score=-0.031661126359778836, total=   1.7s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=5 .........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=5, score=-0.029881240672799254, total=   1.8s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=20 ........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=20, score=-0.04502814413438343, total=   1.6s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=20 ........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=20, score=-0.04630100024306174, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=20 ........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=20, score=-0.04381502209419484, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=20 ........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=20, score=-0.04602136661524285, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=3, min_samples_split=20 ........
# [CV]  max_depth=None, min_samples_leaf=3, min_samples_split=20, score=-0.04571304686430776, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=2 .........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=2, score=-0.035863655627468266, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=2 .........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=2, score=-0.03608177252095772, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=2 .........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=2, score=-0.03275694741396855, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=2 .........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=2, score=-0.035968965206748596, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=2 .........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=2, score=-0.033929802517505686, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=3 .........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=3, score=-0.03540748021832848, total=   1.6s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=3 .........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=3, score=-0.03638413221201064, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=3 .........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=3, score=-0.032733920244654185, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=3 .........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=3, score=-0.035861051749698544, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=3 .........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=3, score=-0.033588064401478976, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=5 .........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=5, score=-0.03522203830555926, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=5 .........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=5, score=-0.03707585545192864, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=5 .........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=5, score=-0.03328142533190068, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=5 .........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=5, score=-0.03502705371946842, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=5 .........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=5, score=-0.03389466286162566, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=20 ........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=20, score=-0.04639267511823911, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=20 ........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=20, score=-0.0474748466570851, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=20 ........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=20, score=-0.04621666902655953, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=20 ........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=20, score=-0.04771029199451165, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=4, min_samples_split=20 ........
# [CV]  max_depth=None, min_samples_leaf=4, min_samples_split=20, score=-0.04701387991323537, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=2 .........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=2, score=-0.03883898039731162, total=   1.7s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=2 .........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=2, score=-0.040757553246847454, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=2 .........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=2, score=-0.037530749872040754, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=2 .........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=2, score=-0.03987557517111712, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=2 .........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=2, score=-0.03773263214461432, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=3 .........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=3, score=-0.03941662777411859, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=3 .........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=3, score=-0.041140348737696564, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=3 .........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=3, score=-0.03699497485349739, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=3 .........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=3, score=-0.040130304196046754, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=3 .........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=3, score=-0.03733615681230594, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=5 .........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=5, score=-0.04012772260882618, total=   1.5s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=5 .........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=5, score=-0.04115967929311546, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=5 .........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=5, score=-0.03704268119438149, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=5 .........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=5, score=-0.03946381057137243, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=5 .........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=5, score=-0.03809377771164113, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=20 ........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=20, score=-0.04859730902919644, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=20 ........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=20, score=-0.04903260871483328, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=20 ........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=20, score=-0.0470668413653084, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=20 ........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=20, score=-0.04956717917952524, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=5, min_samples_split=20 ........
# [CV]  max_depth=None, min_samples_leaf=5, min_samples_split=20, score=-0.047247801997983875, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=2 ........
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=2, score=-0.05697079730214493, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=2 ........
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=2, score=-0.0572946247629597, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=2 ........
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=2, score=-0.056011058637787416, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=2 ........
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=2, score=-0.0596963887172274, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=2 ........
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=2, score=-0.056227295764110494, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=3 ........
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=3, score=-0.056058693941915295, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=3 ........
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=3, score=-0.058139292177756666, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=3 ........
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=3, score=-0.05617201341531246, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=3 ........
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=3, score=-0.05876109618726555, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=3 ........
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=3, score=-0.056360745745897264, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=5 ........
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=5, score=-0.05703196063431574, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=5 ........
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=5, score=-0.05849811106046478, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=5 ........
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=5, score=-0.05457683808583802, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=5 ........
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=5, score=-0.05917730729132603, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=5 ........
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=5, score=-0.05642444957068926, total=   1.4s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=20 .......
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=20, score=-0.05745909486568314, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=20 .......
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=20, score=-0.059242699401752946, total=   1.2s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=20 .......
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=20, score=-0.05616096903765048, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=20 .......
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=20, score=-0.05926225899041197, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=10, min_samples_split=20 .......
# [CV]  max_depth=None, min_samples_leaf=10, min_samples_split=20, score=-0.05633594333370205, total=   1.3s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=2 ........
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=2, score=-0.12698017954593657, total=   1.0s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=2 ........
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=2, score=-0.1269120957746932, total=   0.9s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=2 ........
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=2, score=-0.12170618118843694, total=   0.9s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=2 ........
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=2, score=-0.12842557873860527, total=   0.9s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=2 ........
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=2, score=-0.1306818097120462, total=   0.8s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=3 ........
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=3, score=-0.1266615491572209, total=   0.9s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=3 ........
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=3, score=-0.1267843362930142, total=   0.8s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=3 ........
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=3, score=-0.12147861250342669, total=   0.8s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=3 ........
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=3, score=-0.12822807859653104, total=   0.8s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=3 ........
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=3, score=-0.13130180754641232, total=   0.8s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=5 ........
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=5, score=-0.12717632462305895, total=   0.9s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=5 ........
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=5, score=-0.1281549565785508, total=   0.8s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=5 ........
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=5, score=-0.1221728946064995, total=   0.8s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=5 ........
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=5, score=-0.1264776169374421, total=   0.9s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=5 ........
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=5, score=-0.13135505164368275, total=   0.9s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=20 .......
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=20, score=-0.1259684944247559, total=   0.9s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=20 .......
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=20, score=-0.12758901644899653, total=   0.8s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=20 .......
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=20, score=-0.12164381266283121, total=   0.9s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=20 .......
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=20, score=-0.1283266939012818, total=   0.9s
# [CV] max_depth=None, min_samples_leaf=50, min_samples_split=20 .......
# [CV]  max_depth=None, min_samples_leaf=50, min_samples_split=20, score=-0.13229586246193725, total=   0.8s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=2, score=-0.220092903950303, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=2, score=-0.21579920053671262, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=2, score=-0.20882420929699705, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=2, score=-0.22272819874926264, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=2, score=-0.22500252007263644, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=3 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=3, score=-0.22001607888224586, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=3 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=3, score=-0.215139336059696, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=3 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=3, score=-0.20964481640489394, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=3 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=3, score=-0.22378837662752668, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=3 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=3, score=-0.22536696878510484, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=5 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=5, score=-0.21981592456750204, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=5 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=5, score=-0.21494890072206718, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=5 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=5, score=-0.20989529270225427, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=5 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=5, score=-0.2223396648368796, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=5 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=5, score=-0.22407900346630255, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=20 ...........
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=20, score=-0.2189363717409395, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=20 ...........
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=20, score=-0.2152521527690254, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=20 ...........
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=20, score=-0.20974895399561141, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=20 ...........
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=20, score=-0.22317929310378717, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=20 ...........
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=20, score=-0.22410143794687903, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=2, score=-0.21923850958880098, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=2, score=-0.2147255932322639, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=2, score=-0.20985181095868152, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=2, score=-0.2231443970036193, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=2, score=-0.2264956822746959, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=3 ............
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=3, score=-0.2197647850759341, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=3 ............
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=3, score=-0.21470442808085602, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=3 ............
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=3, score=-0.2092518020187746, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=3 ............
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=3, score=-0.22222266415956154, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=3 ............
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=3, score=-0.22475595196072173, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=5, score=-0.21901141799911655, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=5, score=-0.2145355045530876, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=5, score=-0.20946431859235445, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=5, score=-0.22271663545750736, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=5, score=-0.22487285173422897, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=20, score=-0.21957426062058658, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=20, score=-0.21432544991049782, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=20, score=-0.20846760963001185, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=20, score=-0.22341108056180548, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=2, min_samples_leaf=4, min_samples_split=20, score=-0.2243670690970204, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=2, score=-0.218870193194199, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=2, score=-0.2158749137412918, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=2, score=-0.20939221278267864, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=2, score=-0.22314546822084683, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=2, score=-0.2256998414136486, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=3 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=3, score=-0.21935573983960557, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=3 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=3, score=-0.21526257167685423, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=3 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=3, score=-0.20959999443325542, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=3 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=3, score=-0.22207358708312427, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=3 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=3, score=-0.22480099081976782, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=5 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=5, score=-0.2187670364885112, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=5 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=5, score=-0.21512301736459857, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=5 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=5, score=-0.20977768014975698, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=5 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=5, score=-0.22363955513846773, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=5 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=5, score=-0.22574883918668104, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=20 ...........
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=20, score=-0.21915008019992216, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=20 ...........
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=20, score=-0.21539491834206362, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=20 ...........
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=20, score=-0.20992241864963854, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=20 ...........
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=20, score=-0.22306296565296566, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=20 ...........
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=20, score=-0.2249711807113576, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=2 ...........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=2, score=-0.21908150335327797, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=2 ...........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=2, score=-0.21488553412854183, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=2 ...........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=2, score=-0.21058300855596493, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=2 ...........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=2, score=-0.22330245561371312, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=2 ...........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=2, score=-0.22520663097556026, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=3 ...........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=3, score=-0.2192509691832634, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=3 ...........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=3, score=-0.2145385908450859, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=3 ...........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=3, score=-0.20921705091274728, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=3 ...........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=3, score=-0.22208104086036146, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=3 ...........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=3, score=-0.22536933737041395, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=5, score=-0.22018064402657542, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=5, score=-0.21582185710291818, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=5, score=-0.2085480309463653, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=5, score=-0.22269363993153798, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=5, score=-0.22472681779415918, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=20 ..........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=20, score=-0.21839737072425883, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=20 ..........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=20, score=-0.21424850513989127, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=20 ..........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=20, score=-0.20986935979328925, total=   0.4s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=20 ..........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=20, score=-0.22226007783022567, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=10, min_samples_split=20 ..........
# [CV]  max_depth=2, min_samples_leaf=10, min_samples_split=20, score=-0.22493647006434664, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=2 ...........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=2, score=-0.2194106373362038, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=2 ...........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=2, score=-0.21529299117229803, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=2 ...........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=2, score=-0.20980630751447213, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=2 ...........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=2, score=-0.22308465087190307, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=2 ...........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=2, score=-0.22580206600990443, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=3 ...........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=3, score=-0.21944623200458283, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=3 ...........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=3, score=-0.21521094116181544, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=3 ...........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=3, score=-0.2092114376820364, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=3 ...........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=3, score=-0.22241083064921133, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=3 ...........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=3, score=-0.22452732250847257, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=5 ...........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=5, score=-0.2189989503947054, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=5 ...........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=5, score=-0.21524741450237966, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=5 ...........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=5, score=-0.20931054806791172, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=5 ...........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=5, score=-0.22387738586998895, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=5 ...........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=5, score=-0.22454630520190885, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=20 ..........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=20, score=-0.2196022639294626, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=20 ..........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=20, score=-0.21527912565960156, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=20 ..........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=20, score=-0.209408134818699, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=20 ..........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=20, score=-0.22294113883291536, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=50, min_samples_split=20 ..........
# [CV]  max_depth=2, min_samples_leaf=50, min_samples_split=20, score=-0.22470715623656323, total=   0.3s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=2, score=-0.19276047379585365, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=2, score=-0.18595431197202064, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=2, score=-0.18347240562673778, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=2, score=-0.1896320744233546, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=2, score=-0.19364873229249474, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=3 ............
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=3, score=-0.19237334838247414, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=3 ............
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=3, score=-0.18580580014335418, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=3 ............
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=3, score=-0.1835560797193297, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=3 ............
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=3, score=-0.1886579954054626, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=3 ............
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=3, score=-0.1940831124851937, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=5 ............
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=5, score=-0.19112323524747452, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=5 ............
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=5, score=-0.18556501591727795, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=5 ............
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=5, score=-0.18486321300548741, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=5 ............
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=5, score=-0.1895734531401303, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=5 ............
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=5, score=-0.1933818379900799, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=20 ...........
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=20, score=-0.18991472627288056, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=20 ...........
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=20, score=-0.18616714785375488, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=20 ...........
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=20, score=-0.1848719568935205, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=20 ...........
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=20, score=-0.19000848159683184, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=3, min_samples_split=20 ...........
# [CV]  max_depth=3, min_samples_leaf=3, min_samples_split=20, score=-0.19306976663982264, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=2 ............
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=2, score=-0.19158652429431702, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=2 ............
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=2, score=-0.1864267318734021, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=2 ............
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=2, score=-0.1860453044847718, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=2 ............
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=2, score=-0.18985879333809863, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=2 ............
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=2, score=-0.19479374422201495, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=3 ............
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=3, score=-0.19203702484428334, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=3 ............
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=3, score=-0.1870674837463316, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=3 ............
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=3, score=-0.18423599205954447, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=3 ............
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=3, score=-0.19053583582547284, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=3 ............
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=3, score=-0.19317850889919336, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=5, score=-0.19178865709545034, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=5, score=-0.18583383484194727, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=5, score=-0.18554208765644428, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=5, score=-0.1887610278196724, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=5, score=-0.19424057809781406, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=20, score=-0.19134258839098442, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=20, score=-0.18707023086371585, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=20, score=-0.1837048954429114, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=20, score=-0.19006824500865807, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=3, min_samples_leaf=4, min_samples_split=20, score=-0.19476936293352315, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=2, score=-0.19199712064624969, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=2, score=-0.18791965851002296, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=2, score=-0.18418512176561552, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=2, score=-0.1898351440667385, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=2, score=-0.19466134011118588, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=3 ............
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=3, score=-0.1903621364909023, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=3 ............
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=3, score=-0.18725705557543565, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=3 ............
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=3, score=-0.1854604435255513, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=3 ............
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=3, score=-0.189196181818057, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=3 ............
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=3, score=-0.1942803367355964, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=5 ............
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=5, score=-0.19028081868314314, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=5 ............
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=5, score=-0.18698401845658036, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=5 ............
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=5, score=-0.18544821145195922, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=5 ............
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=5, score=-0.18928562735462023, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=5 ............
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=5, score=-0.19520027473887414, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=20 ...........
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=20, score=-0.19193292977023266, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=20 ...........
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=20, score=-0.18593690117988337, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=20 ...........
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=20, score=-0.1854501082152014, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=20 ...........
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=20, score=-0.18927288369863776, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=5, min_samples_split=20 ...........
# [CV]  max_depth=3, min_samples_leaf=5, min_samples_split=20, score=-0.19383164590656307, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=10, min_samples_split=2 ...........
# [CV]  max_depth=3, min_samples_leaf=10, min_samples_split=2, score=-0.18995885994638703, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=10, min_samples_split=2 ...........
# [CV]  max_depth=3, min_samples_leaf=10, min_samples_split=2, score=-0.18636294436178513, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=10, min_samples_split=2 ...........
# [CV]  max_depth=3, min_samples_leaf=10, min_samples_split=2, score=-0.18676411831281337, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=10, min_samples_split=2 ...........
# [CV]  max_depth=3, min_samples_leaf=10, min_samples_split=2, score=-0.1897359825756263, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=10, min_samples_split=2 ...........
# [CV]  max_depth=3, min_samples_leaf=10, min_samples_split=2, score=-0.19482881302760707, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=10, min_samples_split=3 ...........
# [CV]  max_depth=3, min_samples_leaf=10, min_samples_split=3, score=-0.19076972658849678, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=10, min_samples_split=3 ...........
# [CV]  max_depth=3, min_samples_leaf=10, min_samples_split=3, score=-0.18829425765416552, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=10, min_samples_split=3 ...........
# [CV]  max_depth=3, min_samples_leaf=10, min_samples_split=3, score=-0.18567708629400304, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=10, min_samples_split=3 ...........
# [CV]  max_depth=3, min_samples_leaf=10, min_samples_split=3, score=-0.18917965983108637, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=10, min_samples_split=3 ...........
# [CV]  max_depth=3, min_samples_leaf=10, min_samples_split=3, score=-0.19455591803919803, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=3, min_samples_leaf=10, min_samples_split=5, score=-0.19076719578690363, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=3, min_samples_leaf=10, min_samples_split=5, score=-0.18611840052032047, total=   0.5s
# [CV] max_depth=3, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=3, min_samples_leaf=10, min_samples_split=5, score=-0.18343184686069935, total=   0.5s
# ...
# [CV] max_depth=10, min_samples_leaf=3, min_samples_split=3 ...........
# [CV]  max_depth=10, min_samples_leaf=3, min_samples_split=3, score=-0.06360249345717255, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=3, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=3, min_samples_split=5, score=-0.06610489946632467, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=3, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=3, min_samples_split=5, score=-0.06329352144929559, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=3, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=3, min_samples_split=5, score=-0.0632859120678339, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=3, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=3, min_samples_split=5, score=-0.06058128959870238, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=3, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=3, min_samples_split=5, score=-0.06522649371179895, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=3, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=3, min_samples_split=20, score=-0.07181033477893141, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=3, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=3, min_samples_split=20, score=-0.07042433078704777, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=3, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=3, min_samples_split=20, score=-0.06988856573750984, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=3, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=3, min_samples_split=20, score=-0.06723446943516037, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=3, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=3, min_samples_split=20, score=-0.07191892565908009, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=2 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=2, score=-0.06834375900757875, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=2 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=2, score=-0.065556905532148, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=2 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=2, score=-0.06318921118553242, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=2 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=2, score=-0.06157003334400465, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=2 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=2, score=-0.0662774943936417, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=3 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=3, score=-0.06852427952699068, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=3 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=3, score=-0.06522236905813725, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=3 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=3, score=-0.06330155798721696, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=3 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=3, score=-0.06165758679168934, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=3 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=3, score=-0.06606754794584815, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=5, score=-0.06725603891432302, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=5, score=-0.06571242323816869, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=5, score=-0.06380346988589744, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=5, score=-0.06214268974103016, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=5, score=-0.06675972407204309, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=20, score=-0.07299918732994047, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=20, score=-0.07163098514050113, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=20, score=-0.06832059799992865, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=20, score=-0.0683914896763825, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=20, score=-0.07243206862479669, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=2 ...........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=2, score=-0.06953424586871144, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=2 ...........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=2, score=-0.06780592494545504, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=2 ...........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=2, score=-0.06562997141064991, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=2 ...........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=2, score=-0.06317569349171409, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=2 ...........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=2, score=-0.06851490945066341, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=3 ...........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=3, score=-0.06983272095449419, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=3 ...........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=3, score=-0.06779591623244119, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=3 ...........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=3, score=-0.06514253174971024, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=3 ...........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=3, score=-0.0631283811480536, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=3 ...........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=3, score=-0.0671459205030222, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=5, score=-0.07009111136999897, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=5, score=-0.06814395209235367, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=5, score=-0.06559650064449062, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=5, score=-0.06330911293035006, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=5, score=-0.06954976694892692, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=20, score=-0.07342175281896421, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=20, score=-0.07164986400767648, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=20, score=-0.06935108032005742, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=20, score=-0.06960695412894298, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=5, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=5, min_samples_split=20, score=-0.07258227881672984, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=2 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=2, score=-0.07712799571780002, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=2 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=2, score=-0.07684715040458473, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=2 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=2, score=-0.07546917675143135, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=2 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=2, score=-0.07487777630178738, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=2 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=2, score=-0.07739231287126357, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=3 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=3, score=-0.07767219528899971, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=3 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=3, score=-0.07574281489403757, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=3 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=3, score=-0.07401857953635196, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=3 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=3, score=-0.07473153804626077, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=3 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=3, score=-0.07677469859395052, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=5 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=5, score=-0.0784722489184021, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=5 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=5, score=-0.07717460908188434, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=5 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=5, score=-0.07437845600431117, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=5 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=5, score=-0.07385376071937971, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=5 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=5, score=-0.07785798066061644, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=20 .........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=20, score=-0.07690781067283987, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=20 .........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=20, score=-0.0760699445015192, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=20 .........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=20, score=-0.07552030853890838, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=20 .........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=20, score=-0.07340477291626112, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=20 .........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=20, score=-0.07632725760415045, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=2 ..........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=2, score=-0.12821140434658546, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=2 ..........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=2, score=-0.1282859213500082, total=   0.8s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=2 ..........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=2, score=-0.12273011259448106, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=2 ..........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=2, score=-0.1285405603769744, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=2 ..........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=2, score=-0.13156907782708013, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=3 ..........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=3, score=-0.12967954312741461, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=3 ..........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=3, score=-0.1283872772670489, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=3 ..........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=3, score=-0.12198441125736179, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=3 ..........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=3, score=-0.12820903617695972, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=3 ..........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=3, score=-0.13142688049546372, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=5 ..........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=5, score=-0.1281810415242134, total=   1.0s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=5 ..........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=5, score=-0.1288888596608327, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=5 ..........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=5, score=-0.12163670595614531, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=5 ..........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=5, score=-0.127615497975017, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=5 ..........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=5, score=-0.13134107289881106, total=   1.0s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=20 .........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=20, score=-0.12670006696136085, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=20 .........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=20, score=-0.13030541203576965, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=20 .........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=20, score=-0.1213140795104702, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=20 .........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=20, score=-0.130307444125872, total=   1.0s
# [CV] max_depth=10, min_samples_leaf=50, min_samples_split=20 .........
# [CV]  max_depth=10, min_samples_leaf=50, min_samples_split=20, score=-0.13095971592264802, total=   1.0s
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:  6.8min finished

# %%
print(cv.best_estimator_)
print(cv.best_score_)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=3, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)
# -0.030994846802621885

# %%
# use the best parameters for model tuning, but fit with n_estimators

rf_tuned = RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
           max_features='auto', max_leaf_nodes=None,
           min_impurity_decrease=0.0, min_impurity_split=None,
           min_samples_leaf=3, min_samples_split=2,
           min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=None,
           oob_score=False, random_state=None, verbose=0, warm_start=False)
rf_tuned.fit(X_train,y_train.bookings_pct_finish)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=3, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
rf_tuned.score(X_train,y_train)
# Out:
# 0.9942447185174951

# %%
# Predict using RandomForestClassifier on the test data
y_test_hat = rf_tuned.predict(X_test)

# %%
y_test_hat = y_test_hat.flatten()
y_test_hat = pd.DataFrame(y_test_hat)
display(y_test_hat.head())
# Out:
#           0
# 0  0.849798
# 1  1.097444
# 2  1.181591
# 3  0.911028
# 4  0.443277

# %%
# scoring

from sklearn.metrics import r2_score

r2_scoring = r2_score(y_test,y_test_hat)
print('r2_score')
print(r2_scoring)
print('')
    
def avg_abs_var_finish(y_test,y_test_hat):
    var_finish = np.subtract(y_test,y_test_hat)
    abs_var_finish = abs(var_finish)
    av_abs_var_finish = np.mean(abs_var_finish)
    print('avg_abs_var_finish')
    print(av_abs_var_finish)
    print('')
    
def avg_abs_var_pct(y_test,y_test_hat):
    var_percent = np.subtract(y_test,y_test_hat)/y_test
    abs_var_percent = abs(var_percent)
    av_abs_var_percent = np.mean(abs_var_percent)
    print('av_abs_var_percent')
    print(av_abs_var_percent)
    print('')
    
avg_abs_var_pct(y_test,y_test_hat)

avg_abs_var_finish(y_test,y_test_hat)
# Out:
# r2_score
# 0.9833622201750595
#
# av_abs_var_percent
# bookings_pct_finish    0.027303
# dtype: float64
#
# avg_abs_var_finish
# bookings_pct_finish    0.024573
# dtype: float64

# %%
# export the y_test, compare with actuals

df = pd.concat([X_test_raw.reset_index(), y_test.reset_index(), y_test_hat.reset_index()], axis=1)
df.to_csv("/Users/derekwang/Desktop/Python/Sales Forecast/results_compare__2_random_forest.csv", sep=',')

# %%
#### predict for current quarter ####

# Load the current_quarter_data 
curr_data = pd.read_csv("/Users/derekwang/Desktop/Python/Sales Forecast/testing_data_FY20_Q1.csv")

# Define outcome
outcomes_raw_c = curr_data[['bookings_pct_finish']]

# Define features = removing outcome, dt, and fy_quarter label
features_raw_c1 = curr_data.drop(['direct_bookings', 'bookings_pct_finish'], axis = 1)

features_raw_c = features_raw_c1.drop(['dt', 
                                'fy_quarter', 
                                'day_of_qtr', 
                                'quota', 
                                'stage_1_count', 
                                'stage_1_amount', 
                                'stage_2_count', 
                                'stage_2_amount', 
                                'stage_3_count', 
                                'stage_3_amount', 
                                'stage_4_count', 
                                'stage_4_amount', 
                                'stage_5_count', 
                                'stage_5_amount', 
                                'bookings_qtd',
                                's1_quota_ratio', 's2_quota_ratio', 's3_quota_ratio', 's4_quota_ratio','s5_quota_ratio'       
                                      ], axis = 1)

# fill in NA's with 0 - FEATURES
features_c = features_raw_c.fillna(0.0)

# fill in NA's with 0 - OUTCOMES
outcomes_c = outcomes_raw.fillna(0.0)

# One-hot encoding
X_curr = pd.get_dummies(features_c)

# get rid of blanks in headers
X_curr.columns = X_curr.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# predict
y_curr = rf_tuned.predict(X_curr)

# flatten results
y_curr = y_curr.flatten()
y_curr = pd.DataFrame(y_curr)

# export prediciton
dfc = pd.concat([features_raw_c1.reset_index(), y_curr.reset_index()], axis=1)
dfc.to_csv("/Users/derekwang/Desktop/Python/Sales Forecast/curr_quarter_prediction__2_random_forest.csv", sep=',')
